# %% [markdown]
# # UDACITY SageMaker Essentials: Tying it all Together
#
# ## Using XGBoost in SageMaker
#
#
# To tie everything together, we'll be using Amazon's SageMaker service to construct a random tree model to predict the sentiment of a movie review. This is also a sentiment analysis problem but we won't be using BlazingText. Instead, we will be using the XGBoost package as it is provided to us by Amazon.
#
# ## Instructions
# Once you this notebook is opened in SageMaker Studio, select "Python3(Data Science)" kernel with "ml.g4dn.xlarge" instance.
#
# Some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this notebook. You will not need to modify the included code beyond what is requested. Sections that begin with '**TODO**' in the header indicate that you need to complete or implement some portion within them. Instructions will be provided for each section and the specifics of the implementation are marked in the code block with a `# TODO: ...` comment. Please be sure to read the instructions carefully!

# %% [markdown]
# ## Step 1: Downloading the data
#
# The dataset we are going to use is very popular among researchers in Natural Language Processing, usually referred to as the [IMDb dataset](http://ai.stanford.edu/~amaas/data/sentiment/). It consists of movie reviews from the website [imdb.com](http://www.imdb.com/), each labeled as either '**pos**itive', if the reviewer enjoyed the film, or '**neg**ative' otherwise.
#
# > Maas, Andrew L., et al. [Learning Word Vectors for Sentiment Analysis](http://ai.stanford.edu/~amaas/data/sentiment/). In _Proceedings of the 49th Annual Meeting of the Association for Computational Linguistics: Human Language Technologies_. Association for Computational Linguistics, 2011.
#
# We begin by using some Jupyter Notebook magic to download and extract the dataset.

# %%
# %mkdir ../data
# !wget -O ../data/aclImdb_v1.tar.gz https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# !tar -zxf ../data/aclImdb_v1.tar.gz -C ../data
# Out:
# mkdir: cannot create directory ‘../data’: File exists
# --2023-01-10 23:10:34--  https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# Resolving ai.stanford.edu (ai.stanford.edu)... 171.64.68.10
# Connecting to ai.stanford.edu (ai.stanford.edu)|171.64.68.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84125825 (80M) [application/x-gzip]
# Saving to: ‘../data/aclImdb_v1.tar.gz’
#
# ../data/aclImdb_v1. 100%[===================>]  80.23M  27.8MB/s    in 2.9s
#
# 2023-01-10 23:10:37 (27.8 MB/s) - ‘../data/aclImdb_v1.tar.gz’ saved [84125825/84125825]

# %% [markdown]
# ## Step 2: Preparing the data
#
# The data we have downloaded is split into various files, each of which contains a single review. It will be much easier going forward if we combine these individual files into two large files, one for training and one for testing.

# %%
import os
import glob

def read_imdb_data(data_dir='../data/aclImdb'):
    data = {}
    labels = {}
    
    for data_type in ['train', 'test']:
        data[data_type] = {}
        labels[data_type] = {}
        
        for sentiment in ['pos', 'neg']:
            data[data_type][sentiment] = []
            labels[data_type][sentiment] = []
            
            path = os.path.join(data_dir, data_type, sentiment, '*.txt')
            files = glob.glob(path)
            
            for f in files:
                with open(f) as review:
                    data[data_type][sentiment].append(review.read())
                    # Here we represent a positive review by '1' and a negative review by '0'
                    labels[data_type][sentiment].append(1 if sentiment == 'pos' else 0)
                    
            assert len(data[data_type][sentiment]) == len(labels[data_type][sentiment]), \
                    "{}/{} data size does not match labels size".format(data_type, sentiment)
                
    return data, labels

# %%
data, labels = read_imdb_data()
print("IMDB reviews: train = {} pos / {} neg, test = {} pos / {} neg".format(
            len(data['train']['pos']), len(data['train']['neg']),
            len(data['test']['pos']), len(data['test']['neg'])))
# Out:
# IMDB reviews: train = 12500 pos / 12500 neg, test = 12500 pos / 12500 neg

# %%
from sklearn.utils import shuffle

def prepare_imdb_data(data, labels):
    """Prepare training and test sets from IMDb movie reviews."""
    
    #Combine positive and negative reviews and labels
    data_train = data['train']['pos'] + data['train']['neg']
    data_test = data['test']['pos'] + data['test']['neg']
    labels_train = labels['train']['pos'] + labels['train']['neg']
    labels_test = labels['test']['pos'] + labels['test']['neg']
    
    #Shuffle reviews and corresponding labels within training and test sets
    data_train, labels_train = shuffle(data_train, labels_train)
    data_test, labels_test = shuffle(data_test, labels_test)
    
    # Return a unified training data, test data, training labels, test labets
    return data_train, data_test, labels_train, labels_test

# %%
train_X, test_X, train_y, test_y = prepare_imdb_data(data, labels)
print("IMDb reviews (combined): train = {}, test = {}".format(len(train_X), len(test_X)))
# Out:
# IMDb reviews (combined): train = 25000, test = 25000

# %%
train_X[100]
# Out:
# "Shot into car from through the windscreen, someone is playing someone else their latest song, someone else didn't react, according to the voice-over. I just wonder how that came to be made. There were too many scenes in this movie that I wondered about how come a camera was there. If the scenes shot where the Warhols descended on a BJM post-party are true then that was inexcusable exploitation to the max, if not, then it was a total fabrication, either way it made me uncomfortable, if that was the purpose? All the way thru this movie I kept wondering how the footage came about. Taken at face value, a nice portrait of the (tortured) genius we all believe ourselves to be."

# %% [markdown]
# ## Step 3: Processing the data
#
# Now that we have our training and testing datasets merged and ready to use, we need to start processing the raw data into something that will be useable by our machine learning algorithm. To begin with, we remove any html formatting that may appear in the reviews and perform some standard natural language processing in order to homogenize the data.

# %%
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
from nltk.stem.porter import *
stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
import re
from bs4 import BeautifulSoup

def review_to_words(review):
    text = BeautifulSoup(review, "html.parser").get_text() # Remove HTML tags
    text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower()) # Convert to lower case
    words = text.split() # Split string into words
    words = [w for w in words if w not in stopwords.words("english")] # Remove stopwords
    words = [PorterStemmer().stem(w) for w in words] # stem
    
    return words

# %%
import pickle

cache_dir = os.path.join("../cache", "sentiment_analysis")  # where to store cache files
os.makedirs(cache_dir, exist_ok=True)  # ensure cache directory exists

def preprocess_data(data_train, data_test, labels_train, labels_test,
                    cache_dir=cache_dir, cache_file="preprocessed_data.pkl"):
    """Convert each review to words; read from cache if available."""

    # If cache_file is not None, try to read from it first
    cache_data = None
    if cache_file is not None:
        try:
            with open(os.path.join(cache_dir, cache_file), "rb") as f:
                cache_data = pickle.load(f)
            print("Read preprocessed data from cache file:", cache_file)
        except:
            pass  # unable to read from cache, but that's okay
    
    # If cache is missing, then do the heavy lifting
    if cache_data is None:
        # Preprocess training and test data to obtain words for each review
        #words_train = list(map(review_to_words, data_train))
        #words_test = list(map(review_to_words, data_test))
        words_train = [review_to_words(review) for review in data_train]
        words_test = [review_to_words(review) for review in data_test]
        
        # Write to cache file for future runs
        if cache_file is not None:
            cache_data = dict(words_train=words_train, words_test=words_test,
                              labels_train=labels_train, labels_test=labels_test)
            with open(os.path.join(cache_dir, cache_file), "wb") as f:
                pickle.dump(cache_data, f)
            print("Wrote preprocessed data to cache file:", cache_file)
    else:
        # Unpack data loaded from cache file
        words_train, words_test, labels_train, labels_test = (cache_data['words_train'],
                cache_data['words_test'], cache_data['labels_train'], cache_data['labels_test'])
    
    return words_train, words_test, labels_train, labels_test

# %%
# Preprocess data
train_X, test_X, train_y, test_y = preprocess_data(train_X, test_X, train_y, test_y)
# Out:
# Wrote preprocessed data to cache file: preprocessed_data.pkl

# %% [markdown]
# ### Extract Bag-of-Words features
#
# For the model we will be implementing, rather than using the reviews directly, we are going to transform each review into a Bag-of-Words feature representation. Keep in mind that 'in the wild' we will only have access to the training set so our transformer can only use the training set to construct a representation.

# %%
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
import joblib
# joblib is an enhanced version of pickle that is more efficient for storing NumPy arrays

def extract_BoW_features(words_train, words_test, vocabulary_size=5000,
                         cache_dir=cache_dir, cache_file="bow_features.pkl"):
    """Extract Bag-of-Words for a given set of documents, already preprocessed into words."""
    
    # If cache_file is not None, try to read from it first
    cache_data = None
    if cache_file is not None:
        try:
            with open(os.path.join(cache_dir, cache_file), "rb") as f:
                cache_data = joblib.load(f)
            print("Read features from cache file:", cache_file)
        except:
            pass  # unable to read from cache, but that's okay
    
    # If cache is missing, then do the heavy lifting
    if cache_data is None:
        # Fit a vectorizer to training documents and use it to transform them
        # NOTE: Training documents have already been preprocessed and tokenized into words;
        #       pass in dummy functions to skip those steps, e.g. preprocessor=lambda x: x
        vectorizer = CountVectorizer(max_features=vocabulary_size,
                preprocessor=lambda x: x, tokenizer=lambda x: x)  # already preprocessed
        features_train = vectorizer.fit_transform(words_train).toarray()

        # Apply the same vectorizer to transform the test documents (ignore unknown words)
        features_test = vectorizer.transform(words_test).toarray()
        
        # NOTE: Remember to convert the features using .toarray() for a compact representation
        
        # Write to cache file for future runs (store vocabulary as well)
        if cache_file is not None:
            vocabulary = vectorizer.vocabulary_
            cache_data = dict(features_train=features_train, features_test=features_test,
                             vocabulary=vocabulary)
            with open(os.path.join(cache_dir, cache_file), "wb") as f:
                joblib.dump(cache_data, f)
            print("Wrote features to cache file:", cache_file)
    else:
        # Unpack data loaded from cache file
        features_train, features_test, vocabulary = (cache_data['features_train'],
                cache_data['features_test'], cache_data['vocabulary'])
    
    # Return both the extracted features as well as the vocabulary
    return features_train, features_test, vocabulary

# %%
# Extract Bag of Words features for both training and test datasets
train_X, test_X, vocabulary = extract_BoW_features(train_X, test_X)
# Out:
# Wrote features to cache file: bow_features.pkl

# %% [markdown]
# ## Step 4: Classification using XGBoost
#
# Now that we have created the feature representation of our training (and testing) data, it is time to start setting up and using the XGBoost classifier provided by SageMaker.
#
# ### (TODO) Writing the dataset
#
# The XGBoost classifier that we will be using requires the dataset to be written to a file and stored using Amazon S3. To do this, we will start by splitting the training dataset into two parts, the data we will train the model with and a validation set. Then, we will write those datasets to a file and upload the files to S3. In addition, we will write the test set input to a file and upload the file to S3. This is so that we can use SageMakers Batch Transform functionality to test our model once we've fit it.

# %%
import pandas as pd

# TODO: Split the train_X and train_y arrays into the DataFrames val_X, train_X and val_y, train_y. 
# Make sure that val_X and val_y contain 10000 entires while train_X and train_y contain the remaining 15000 entries.

val_X = pd.DataFrame(train_X[:10000])
train_X = pd.DataFrame(train_X[10000:])
val_y = pd.DataFrame(train_y[:10000])
train_y = pd.DataFrame(train_y[10000:])

# %% [markdown]
# The documentation for the XGBoost algorithm in SageMaker requires that the saved datasets should contain no headers or index and that for the training and validation data, the label should occur first for each sample.
#
# For more information about this and other algorithms, the SageMaker developer documentation can be found on __[Amazon's website.](https://docs.aws.amazon.com/sagemaker/latest/dg/)__

# %%
# First we make sure that the local directory in which we'd like to store the training and validation csv files exists.
data_dir = '../data/xgboost'
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

# %%
# Then, save the test data to test.csv in the data_dir directory. Note that we do not save the associated ground truth
# labels, instead we will use them later to compare with our model output.

pd.DataFrame(test_X).to_csv(os.path.join(data_dir, 'test.csv'), header=False, index=False)

# TODO: Save the training and validation data to train.csv and validation.csv in the data_dir directory.
# Make sure that the files you create include the ground truth and are in the correct format.

pd.concat([val_y, val_X], axis=1).to_csv(os.path.join(data_dir, 'validation.csv'), header=False, index=False)
pd.concat([train_y, train_X], axis=1).to_csv(os.path.join(data_dir, 'train.csv'), header=False, index=False)

# %%
# To save a bit of memory we can set text_X, train_X, val_X, train_y and val_y to None.

test_X = train_X = val_X = train_y = val_y = None

# %% [markdown]
# ### (TODO) Uploading Training / Validation files to S3
#
# Amazon's S3 service allows us to store files that can be access by both the built-in training models such as the XGBoost model we will be using as well as custom models such as the one we will see a little later.
#
# For this, and most other tasks we will be doing using SageMaker, there are two methods we could use. The first is to use the low level functionality of SageMaker which requires knowing each of the objects involved in the SageMaker environment. The second is to use the high level functionality in which certain choices have been made on the user's behalf. The low level approach benefits from allowing the user a great deal of flexibility while the high level approach makes development much quicker. For our purposes we will opt to use the high level approach although using the low-level approach is certainly an option.
#
# The method `upload_data()`, a member of the object representing our current SageMaker session, may be of use to you. What this method does is upload the data to the default bucket (which is created if it does not exist) into the path described by the key_prefix variable. To see this for yourself, once you have uploaded the data files, go to the S3 console and look to see where the files have been uploaded.
#
# For additional resources, see the __[SageMaker session.upload_data](https://sagemaker.readthedocs.io/en/latest/session.html#sagemaker.session.Session.upload_data)__ and in addition the __[SageMaker Developer Guide.](https://docs.aws.amazon.com/sagemaker/latest/dg/)__

# %%
import sagemaker

session = sagemaker.Session() # Store the current SageMaker session

# S3 prefix (which folder will we use)
prefix = 'lesson2/exercise5/sentiment-xgboost'

# TODO: Upload the test.csv, train.csv and validation.csv files which are contained in data_dir to S3 using sess.upload_data().
test_location = session.upload_data(os.path.join(data_dir, 'test.csv'), key_prefix=prefix)
val_location = session.upload_data(os.path.join(data_dir, 'validation.csv'), key_prefix=prefix)
train_location = session.upload_data(os.path.join(data_dir, 'train.csv'), key_prefix=prefix)

# %% [markdown]
# ### (TODO) Creating the XGBoost model
#
# Now that the data has been uploaded it is time to create the XGBoost model. To begin with, we need to do some setup. At this point it is worth discussing what a model is in SageMaker. It is easiest to think of a model of comprising three different objects in the SageMaker ecosystem, which interact with one another.
#
# - Model Artifacts
# - Training Code (Container)
# - Inference Code (Container)
#
# The Model Artifacts are what you might think of as the actual model itself. For example, if you were building a neural network, the model artifacts would be the weights of the various layers. In our case, for an XGBoost model, the artifacts are the actual trees that are created during training.
#
# The other two objects, the training code and the inference code are then used the manipulate the training artifacts. More precisely, the training code uses the training data that is provided and creates the model artifacts, while the inference code uses the model artifacts to make predictions on new data.
#
# The way that SageMaker runs the training and inference code is by making use of Docker containers. For now, think of a container as being a way of packaging code up so that dependencies aren't an issue.

# %%
from sagemaker import get_execution_role

# Our current execution role is require when creating the model as the training
# and inference code will need to access the model artifacts.
role = get_execution_role()

# %%
# We need to retrieve the location of the container which is provided by Amazon for using XGBoost.
# As a matter of convenience, the training and inference code both use the same container.
from sagemaker import image_uris
container = image_uris.retrieve('xgboost', session.boto_region_name, 'latest')

# %%
# TODO: Create a SageMaker estimator using the container location determined in the previous cell.
#       It is recommended that you use a single training instance of type ml.m4.xlarge. It is also
#       recommended that you use 's3://{}/{}/output'.format(session.default_bucket(), prefix) as the
#       output path.

xgb = sagemaker.estimator.Estimator(container, # The location of the container we wish to use
                                    role,                                    # What is our current IAM Role
                                    instance_count=1,                  # How many compute instances
                                    instance_type='ml.m4.xlarge',      # What kind of compute instances
                                    output_path='s3://{}/{}/output'.format(session.default_bucket(), prefix),
                                    sagemaker_session=session)

# TODO: Set the XGBoost hyperparameters in the xgb object. Don't forget that in this case we have a binary
#       label so we should be using the 'binary:logistic' objective.

xgb.set_hyperparameters(max_depth=5,
                        eta=0.2,
                        gamma=4,
                        min_child_weight=6,
                        subsample=0.8,
                        silent=0,
                        objective='binary:logistic',
                        early_stopping_rounds=10,
                        num_round=500)

# %% [markdown]
# ### Fit the XGBoost model
#
# Now that our model has been set up we simply need to attach the training and validation datasets and then ask SageMaker to set up the computation.

# %%
s3_input_train = sagemaker.TrainingInput(s3_data=train_location, content_type='csv')
s3_input_validation = sagemaker.TrainingInput(s3_data=val_location, content_type='csv')

# %%
xgb.fit({'train': s3_input_train, 'validation': s3_input_validation})
# Out:
# 2023-01-11 01:06:55 Starting - Starting the training job...
# 2023-01-11 01:07:22 Starting - Preparing the instances for trainingProfilerReport-1673399215: InProgress
# ............
# 2023-01-11 01:09:20 Downloading - Downloading input data...
# 2023-01-11 01:09:42 Training - Downloading the training image...
# 2023-01-11 01:10:21 Training - Training image download completed. Training in progress..Arguments: train
# [2023-01-11:01:10:23:INFO] Running standalone xgboost training.
# [2023-01-11:01:10:23:INFO] File size need to be processed in the node: 238.47mb. Available memory size in the node: 8622.68mb
# [2023-01-11:01:10:23:INFO] Determined delimiter of CSV input is ','
# [01:10:23] S3DistributionType set as FullyReplicated
# [01:10:25] 15000x5000 matrix with 75000000 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2023-01-11:01:10:25:INFO] Determined delimiter of CSV input is ','
# [01:10:25] S3DistributionType set as FullyReplicated
# [01:10:26] 10000x5000 matrix with 50000000 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [01:10:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 4 pruned nodes, max_depth=5
# [0]#011train-error:0.2808#011validation-error:0.2925
# Multiple eval metrics have been passed: 'validation-error' will be used for early stopping.
# Will train until validation-error hasn't improved in 10 rounds.
# [01:10:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 6 pruned nodes, max_depth=5
# [1]#011train-error:0.279333#011validation-error:0.2883
# [01:10:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 8 pruned nodes, max_depth=5
# [2]#011train-error:0.276#011validation-error:0.2868
# [01:10:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 2 pruned nodes, max_depth=5
# [3]#011train-error:0.266733#011validation-error:0.2761
# [01:10:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 2 pruned nodes, max_depth=5
# [4]#011train-error:0.2578#011validation-error:0.2704
# [01:10:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 8 pruned nodes, max_depth=5
# [5]#011train-error:0.251733#011validation-error:0.2636
# [01:10:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 8 pruned nodes, max_depth=5
# [6]#011train-error:0.2364#011validation-error:0.2488
# [01:10:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 4 pruned nodes, max_depth=5
# [7]#011train-error:0.2392#011validation-error:0.2536
# [01:10:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 8 pruned nodes, max_depth=5
# [8]#011train-error:0.229333#011validation-error:0.2431
# [01:10:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 6 pruned nodes, max_depth=5
# [9]#011train-error:0.226267#011validation-error:0.24
# [01:10:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 6 pruned nodes, max_depth=5
# [10]#011train-error:0.217933#011validation-error:0.2357
# [01:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 12 pruned nodes, max_depth=5
# [11]#011train-error:0.2122#011validation-error:0.2284
# [01:10:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 12 pruned nodes, max_depth=5
# [12]#011train-error:0.2098#011validation-error:0.226
# [01:10:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 14 pruned nodes, max_depth=5
# [13]#011train-error:0.206467#011validation-error:0.2229
# [01:10:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 4 pruned nodes, max_depth=5
# [14]#011train-error:0.206467#011validation-error:0.222
# [01:10:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 8 pruned nodes, max_depth=5
# [15]#011train-error:0.205067#011validation-error:0.219
# [01:10:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 10 pruned nodes, max_depth=5
# [16]#011train-error:0.200733#011validation-error:0.2169
# [01:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 4 pruned nodes, max_depth=5
# [17]#011train-error:0.198#011validation-error:0.2166
# [01:10:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 8 pruned nodes, max_depth=5
# [18]#011train-error:0.194533#011validation-error:0.2129
# [01:10:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 10 pruned nodes, max_depth=5
# [19]#011train-error:0.189733#011validation-error:0.2093
# [01:10:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 10 pruned nodes, max_depth=5
# [20]#011train-error:0.188733#011validation-error:0.2053
# [01:10:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 12 pruned nodes, max_depth=5
# [21]#011train-error:0.186667#011validation-error:0.2035
# [01:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 10 pruned nodes, max_depth=5
# [22]#011train-error:0.183667#011validation-error:0.204
# [01:11:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 4 pruned nodes, max_depth=5
# [23]#011train-error:0.182067#011validation-error:0.2031
# [01:11:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 8 pruned nodes, max_depth=5
# [24]#011train-error:0.179333#011validation-error:0.2002
# [01:11:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 10 pruned nodes, max_depth=5
# [25]#011train-error:0.1764#011validation-error:0.198
# [01:11:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 4 pruned nodes, max_depth=5
# [26]#011train-error:0.173733#011validation-error:0.1961
# [01:11:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 14 pruned nodes, max_depth=5
# [27]#011train-error:0.1706#011validation-error:0.1949
# [01:11:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 10 pruned nodes, max_depth=5
# [28]#011train-error:0.168733#011validation-error:0.1932
# [01:11:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 8 pruned nodes, max_depth=5
# [29]#011train-error:0.167#011validation-error:0.1923
# [01:11:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 12 pruned nodes, max_depth=5
# [30]#011train-error:0.1658#011validation-error:0.1908
# [01:11:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 14 pruned nodes, max_depth=5
# [31]#011train-error:0.164267#011validation-error:0.1892
# [01:11:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 10 pruned nodes, max_depth=5
# [32]#011train-error:0.163067#011validation-error:0.1869
# [01:11:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 14 pruned nodes, max_depth=5
# [33]#011train-error:0.161667#011validation-error:0.1866
# [01:11:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 8 pruned nodes, max_depth=5
# [34]#011train-error:0.160467#011validation-error:0.1863
# [01:11:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 6 pruned nodes, max_depth=5
# [35]#011train-error:0.1596#011validation-error:0.1855
# [01:11:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 10 pruned nodes, max_depth=5
# [36]#011train-error:0.1588#011validation-error:0.1842
# [01:11:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 4 pruned nodes, max_depth=5
# [37]#011train-error:0.155267#011validation-error:0.1833
# [01:11:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 4 pruned nodes, max_depth=5
# [38]#011train-error:0.154133#011validation-error:0.181
# [01:11:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 10 pruned nodes, max_depth=5
# [39]#011train-error:0.1532#011validation-error:0.1811
# [01:11:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 4 pruned nodes, max_depth=5
# [40]#011train-error:0.152267#011validation-error:0.1805
# [01:11:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 12 pruned nodes, max_depth=5
# [41]#011train-error:0.15#011validation-error:0.1795
# [01:11:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 8 pruned nodes, max_depth=5
# [42]#011train-error:0.149#011validation-error:0.1778
# [01:11:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 16 pruned nodes, max_depth=5
# [43]#011train-error:0.147933#011validation-error:0.1761
# [01:11:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 10 pruned nodes, max_depth=5
# [44]#011train-error:0.147267#011validation-error:0.1751
# [01:11:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 10 pruned nodes, max_depth=5
# [45]#011train-error:0.146267#011validation-error:0.1749
# [01:11:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 8 pruned nodes, max_depth=5
# [46]#011train-error:0.144667#011validation-error:0.1742
# [01:11:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 18 pruned nodes, max_depth=5
# [47]#011train-error:0.143267#011validation-error:0.173
# [01:11:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 6 pruned nodes, max_depth=5
# [48]#011train-error:0.142#011validation-error:0.1725
# [01:11:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 12 pruned nodes, max_depth=5
# [49]#011train-error:0.1418#011validation-error:0.173
# [01:11:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 10 pruned nodes, max_depth=5
# [50]#011train-error:0.139933#011validation-error:0.1735
# [01:11:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 8 pruned nodes, max_depth=5
# [51]#011train-error:0.1388#011validation-error:0.1723
# [01:11:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 10 pruned nodes, max_depth=5
# [52]#011train-error:0.1388#011validation-error:0.1709
# [01:11:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 6 pruned nodes, max_depth=5
# [53]#011train-error:0.1368#011validation-error:0.1695
# [01:11:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 8 pruned nodes, max_depth=5
# [54]#011train-error:0.135667#011validation-error:0.1686
# [01:11:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 6 pruned nodes, max_depth=5
# [55]#011train-error:0.135333#011validation-error:0.1682
# [01:11:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 14 pruned nodes, max_depth=5
# [56]#011train-error:0.133333#011validation-error:0.1693
# [01:11:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 16 pruned nodes, max_depth=5
# [57]#011train-error:0.132733#011validation-error:0.1681
# [01:11:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 14 pruned nodes, max_depth=5
# [58]#011train-error:0.132333#011validation-error:0.1684
# [01:11:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 14 pruned nodes, max_depth=5
# [59]#011train-error:0.1318#011validation-error:0.1675
# [01:11:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 12 pruned nodes, max_depth=5
# [60]#011train-error:0.130267#011validation-error:0.1669
# [01:11:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 8 pruned nodes, max_depth=5
# [61]#011train-error:0.128933#011validation-error:0.167
# [01:11:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 14 pruned nodes, max_depth=5
# [62]#011train-error:0.127467#011validation-error:0.1657
# [01:11:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 14 pruned nodes, max_depth=5
# [63]#011train-error:0.1266#011validation-error:0.1649
# [01:11:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 10 pruned nodes, max_depth=5
# [64]#011train-error:0.126133#011validation-error:0.1656
# [01:11:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 6 pruned nodes, max_depth=5
# [65]#011train-error:0.124133#011validation-error:0.1632
# [01:12:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 6 pruned nodes, max_depth=5
# [66]#011train-error:0.1228#011validation-error:0.1633
# [01:12:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 10 pruned nodes, max_depth=5
# [67]#011train-error:0.1222#011validation-error:0.1631
# [01:12:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 14 pruned nodes, max_depth=5
# [68]#011train-error:0.1214#011validation-error:0.1628
# [01:12:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 10 pruned nodes, max_depth=5
# [69]#011train-error:0.120533#011validation-error:0.1629
# [01:12:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [70]#011train-error:0.120333#011validation-error:0.1631
# [01:12:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 18 pruned nodes, max_depth=5
# [71]#011train-error:0.119933#011validation-error:0.1629
# [01:12:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 4 pruned nodes, max_depth=5
# [72]#011train-error:0.118733#011validation-error:0.1628
# [01:12:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 10 pruned nodes, max_depth=5
# [73]#011train-error:0.118333#011validation-error:0.1627
# [01:12:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 10 pruned nodes, max_depth=5
# [74]#011train-error:0.117#011validation-error:0.1617
# [01:12:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [75]#011train-error:0.117267#011validation-error:0.1612
# [01:12:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 10 pruned nodes, max_depth=5
# [76]#011train-error:0.1172#011validation-error:0.1614
# [01:12:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 12 pruned nodes, max_depth=5
# [77]#011train-error:0.1176#011validation-error:0.161
# [01:12:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4 pruned nodes, max_depth=5
# [78]#011train-error:0.117533#011validation-error:0.1604
# [01:12:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 12 pruned nodes, max_depth=5
# [79]#011train-error:0.1156#011validation-error:0.1595
# [01:12:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 8 pruned nodes, max_depth=5
# [80]#011train-error:0.114467#011validation-error:0.1593
# [01:12:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 8 pruned nodes, max_depth=5
# [81]#011train-error:0.113333#011validation-error:0.1578
# [01:12:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [82]#011train-error:0.112467#011validation-error:0.1576
# [01:12:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 10 pruned nodes, max_depth=5
# [83]#011train-error:0.112933#011validation-error:0.1582
# [01:12:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4 pruned nodes, max_depth=5
# [84]#011train-error:0.1128#011validation-error:0.1581
# [01:12:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=5
# [85]#011train-error:0.112533#011validation-error:0.1577
# [01:12:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 22 pruned nodes, max_depth=5
# [86]#011train-error:0.1124#011validation-error:0.1574
# [01:12:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 12 pruned nodes, max_depth=5
# [87]#011train-error:0.1124#011validation-error:0.1571
# [01:12:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=5
# [88]#011train-error:0.111267#011validation-error:0.1568
# [01:12:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 10 pruned nodes, max_depth=5
# [89]#011train-error:0.111067#011validation-error:0.157
# [01:12:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 8 pruned nodes, max_depth=5
# [90]#011train-error:0.1104#011validation-error:0.1573
# [01:12:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [91]#011train-error:0.110133#011validation-error:0.1578
# [01:12:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [92]#011train-error:0.109533#011validation-error:0.1572
# [01:12:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 8 pruned nodes, max_depth=5
# [93]#011train-error:0.108333#011validation-error:0.1561
# [01:12:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 12 pruned nodes, max_depth=5
# [94]#011train-error:0.108667#011validation-error:0.156
# [01:12:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 6 pruned nodes, max_depth=5
# [95]#011train-error:0.108333#011validation-error:0.1548
# [01:12:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 12 pruned nodes, max_depth=5
# [96]#011train-error:0.107533#011validation-error:0.1535
# [01:12:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=5
# [97]#011train-error:0.1076#011validation-error:0.1538
# [01:12:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 4 pruned nodes, max_depth=5
# [98]#011train-error:0.106267#011validation-error:0.1538
# [01:12:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 6 pruned nodes, max_depth=5
# [99]#011train-error:0.105133#011validation-error:0.1537
# [01:12:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=5
# [100]#011train-error:0.104733#011validation-error:0.1531
# [01:12:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 4 pruned nodes, max_depth=5
# [101]#011train-error:0.104067#011validation-error:0.1526
# [01:12:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 16 pruned nodes, max_depth=5
# [102]#011train-error:0.1046#011validation-error:0.1521
# [01:12:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [103]#011train-error:0.104267#011validation-error:0.1526
# [01:12:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 14 pruned nodes, max_depth=5
# [104]#011train-error:0.104#011validation-error:0.1534
# [01:12:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [105]#011train-error:0.1042#011validation-error:0.153
# [01:12:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=5
# [106]#011train-error:0.1034#011validation-error:0.1525
# [01:12:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 10 pruned nodes, max_depth=5
# [107]#011train-error:0.1032#011validation-error:0.1528
# [01:13:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=5
# [108]#011train-error:0.102467#011validation-error:0.1524
# [01:13:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 12 pruned nodes, max_depth=5
# [109]#011train-error:0.102267#011validation-error:0.1518
# [01:13:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 14 pruned nodes, max_depth=5
# [110]#011train-error:0.102933#011validation-error:0.1503
# [01:13:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 12 pruned nodes, max_depth=5
# [111]#011train-error:0.102133#011validation-error:0.1496
# [01:13:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [112]#011train-error:0.102267#011validation-error:0.1496
# [01:13:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 14 pruned nodes, max_depth=5
# [113]#011train-error:0.101667#011validation-error:0.149
# [01:13:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 12 pruned nodes, max_depth=5
# [114]#011train-error:0.101267#011validation-error:0.1484
# [01:13:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 8 pruned nodes, max_depth=5
# [115]#011train-error:0.101333#011validation-error:0.1489
# [01:13:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 2 pruned nodes, max_depth=5
# [116]#011train-error:0.101467#011validation-error:0.1487
# [01:13:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=5
# [117]#011train-error:0.101533#011validation-error:0.1487
# [01:13:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 12 pruned nodes, max_depth=5
# [118]#011train-error:0.101#011validation-error:0.1487
# [01:13:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 6 pruned nodes, max_depth=5
# [119]#011train-error:0.100933#011validation-error:0.1494
# [01:13:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 10 pruned nodes, max_depth=5
# [120]#011train-error:0.100267#011validation-error:0.1491
# [01:13:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 8 pruned nodes, max_depth=5
# [121]#011train-error:0.099133#011validation-error:0.1489
# [01:13:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=5
# [122]#011train-error:0.098733#011validation-error:0.1477
# [01:13:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 12 pruned nodes, max_depth=5
# [123]#011train-error:0.099533#011validation-error:0.1477
# [01:13:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 14 pruned nodes, max_depth=5
# [124]#011train-error:0.099333#011validation-error:0.1476
# [01:13:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=5
# [125]#011train-error:0.098867#011validation-error:0.1469
# [01:13:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [126]#011train-error:0.0988#011validation-error:0.1467
# [01:13:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [127]#011train-error:0.0988#011validation-error:0.1468
# [01:13:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [128]#011train-error:0.099#011validation-error:0.1472
# [01:13:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=5
# [129]#011train-error:0.098467#011validation-error:0.1463
# [01:13:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=5
# [130]#011train-error:0.0978#011validation-error:0.146
# [01:13:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 12 pruned nodes, max_depth=5
# [131]#011train-error:0.098067#011validation-error:0.145
# [01:13:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 10 pruned nodes, max_depth=5
# [132]#011train-error:0.097267#011validation-error:0.1441
# [01:13:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [133]#011train-error:0.0966#011validation-error:0.1442
# [01:13:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 14 pruned nodes, max_depth=5
# [134]#011train-error:0.095667#011validation-error:0.143
# [01:13:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 12 pruned nodes, max_depth=5
# [135]#011train-error:0.095333#011validation-error:0.1445
# [01:13:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=5
# [136]#011train-error:0.095067#011validation-error:0.1446
# [01:13:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 8 pruned nodes, max_depth=5
# [137]#011train-error:0.094733#011validation-error:0.1436
# [01:13:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 6 pruned nodes, max_depth=5
# [138]#011train-error:0.094733#011validation-error:0.1429
# [01:13:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 12 pruned nodes, max_depth=5
# [139]#011train-error:0.094467#011validation-error:0.1432
# [01:13:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [140]#011train-error:0.0944#011validation-error:0.1426
# [01:13:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=5
# [141]#011train-error:0.094267#011validation-error:0.1425
# [01:13:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 14 pruned nodes, max_depth=5
# [142]#011train-error:0.093933#011validation-error:0.1433
# [01:13:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [143]#011train-error:0.0938#011validation-error:0.1433
# [01:13:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 8 pruned nodes, max_depth=5
# [144]#011train-error:0.093533#011validation-error:0.1434
# [01:13:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 6 pruned nodes, max_depth=5
# [145]#011train-error:0.093467#011validation-error:0.1422
# [01:13:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 10 pruned nodes, max_depth=5
# [146]#011train-error:0.092333#011validation-error:0.142
# [01:13:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 12 pruned nodes, max_depth=5
# [147]#011train-error:0.092133#011validation-error:0.1421
# [01:13:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 14 pruned nodes, max_depth=5
# [148]#011train-error:0.0924#011validation-error:0.1414
# [01:13:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [149]#011train-error:0.092533#011validation-error:0.1414
# [01:13:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [150]#011train-error:0.092#011validation-error:0.1413
# [01:13:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 12 pruned nodes, max_depth=5
# [151]#011train-error:0.091733#011validation-error:0.1411
# [01:14:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [152]#011train-error:0.0912#011validation-error:0.1404
# [01:14:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=5
# [153]#011train-error:0.091733#011validation-error:0.1404
# [01:14:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 8 pruned nodes, max_depth=5
# [154]#011train-error:0.090933#011validation-error:0.1411
# [01:14:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [155]#011train-error:0.0904#011validation-error:0.1409
# [01:14:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 6 pruned nodes, max_depth=5
# [156]#011train-error:0.089067#011validation-error:0.14
# [01:14:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2 pruned nodes, max_depth=5
# [157]#011train-error:0.089#011validation-error:0.1402
# [01:14:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [158]#011train-error:0.088333#011validation-error:0.1398
# [01:14:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [159]#011train-error:0.088#011validation-error:0.1392
# [01:14:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [160]#011train-error:0.088133#011validation-error:0.1392
# [01:14:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [161]#011train-error:0.087867#011validation-error:0.1392
# [01:14:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [162]#011train-error:0.087667#011validation-error:0.1389
# [01:14:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 14 pruned nodes, max_depth=5
# [163]#011train-error:0.0874#011validation-error:0.1385
# [01:14:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=5
# [164]#011train-error:0.087333#011validation-error:0.138
# [01:14:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 10 pruned nodes, max_depth=5
# [165]#011train-error:0.087#011validation-error:0.1383
# [01:14:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [166]#011train-error:0.087133#011validation-error:0.1384
# [01:14:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=5
# [167]#011train-error:0.087133#011validation-error:0.1381
# [01:14:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [168]#011train-error:0.086667#011validation-error:0.138
# [01:14:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 8 pruned nodes, max_depth=5
# [169]#011train-error:0.085333#011validation-error:0.1379
# [01:14:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [170]#011train-error:0.084733#011validation-error:0.1383
# [01:14:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 10 pruned nodes, max_depth=5
# [171]#011train-error:0.084467#011validation-error:0.1388
# [01:14:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 8 pruned nodes, max_depth=5
# [172]#011train-error:0.084133#011validation-error:0.1391
#
# 2023-01-11 01:14:44 Uploading - Uploading generated training model[01:14:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 12 pruned nodes, max_depth=5
# [173]#011train-error:0.084067#011validation-error:0.139
# [01:14:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 2 pruned nodes, max_depth=5
# [174]#011train-error:0.084467#011validation-error:0.1392
# [01:14:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 6 pruned nodes, max_depth=5
# [175]#011train-error:0.084133#011validation-error:0.139
# [01:14:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=5
# [176]#011train-error:0.083867#011validation-error:0.1385
# [01:14:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4 pruned nodes, max_depth=5
# [177]#011train-error:0.083133#011validation-error:0.1386
# [01:14:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 8 pruned nodes, max_depth=5
# [178]#011train-error:0.082867#011validation-error:0.1389
# [01:14:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 10 pruned nodes, max_depth=5
# [179]#011train-error:0.082067#011validation-error:0.138
# Stopping. Best iteration:
# [169]#011train-error:0.085333#011validation-error:0.1379
# 2023-01-11 01:15:02 Completed - Training job completed
# ProfilerReport-1673399215: NoIssuesFound
# Training seconds: 358
# Billable seconds: 358

# %% [markdown]
# ### (TODO) Testing the model
#
# Now that we've fit our XGBoost model, it's time to see how well it performs. To do this we will use SageMakers Batch Transform functionality. Batch Transform is a convenient way to perform inference on a large dataset in a way that is not realtime. That is, we don't necessarily need to use our model's results immediately and instead we can peform inference on a large number of samples. An example of this in industry might be peforming an end of month report. This method of inference can also be useful to us as it means to can perform inference on our entire test set.
#
# To perform a Batch Transformation we need to first create a transformer objects from our trained estimator object.

# %%
# TODO: Create a transformer object from the trained model. 
# Using an instance count of 1 and an instance type of ml.m4.xlarge should be more than enough.
xgb_transformer = xgb.transformer(instance_count = 1, instance_type = 'ml.m4.xlarge')

# %% [markdown]
# Next we actually perform the transform job. When doing so we need to make sure to specify the type of data we are sending so that it is serialized correctly in the background. In our case we are providing our model with csv data so we specify `text/csv`. Also, if the test data that we have provided is too large to process all at once then we need to specify how the data file should be split up. Since each line is a single entry in our data set we tell SageMaker that it can split the input on each line.

# %%
# TODO: Start the transform job. Make sure to specify the content type and the split type of the test data.
xgb_transformer.transform(test_location, content_type='text/csv', split_type='Line')
# Out:
# ....................................Arguments: serve
# [2023-01-11 01:22:39 +0000] [1] [INFO] Starting gunicorn 19.9.0
# [2023-01-11 01:22:39 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2023-01-11 01:22:39 +0000] [1] [INFO] Using worker: gevent
# [2023-01-11 01:22:39 +0000] [21] [INFO] Booting worker with pid: 21
# [2023-01-11 01:22:39 +0000] [22] [INFO] Booting worker with pid: 22
# Arguments: serve
# [2023-01-11 01:22:39 +0000] [1] [INFO] Starting gunicorn 19.9.0
# [2023-01-11 01:22:39 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2023-01-11 01:22:39 +0000] [1] [INFO] Using worker: gevent
# [2023-01-11 01:22:39 +0000] [21] [INFO] Booting worker with pid: 21
# [2023-01-11 01:22:39 +0000] [22] [INFO] Booting worker with pid: 22
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2023-01-11:01:22:39:INFO] Model loaded successfully for worker : 21
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2023-01-11:01:22:39:INFO] Model loaded successfully for worker : 22
# [2023-01-11 01:22:39 +0000] [23] [INFO] Booting worker with pid: 23
# [2023-01-11 01:22:39 +0000] [24] [INFO] Booting worker with pid: 24
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2023-01-11:01:22:39:INFO] Model loaded successfully for worker : 23
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2023-01-11:01:22:39:INFO] Model loaded successfully for worker : 24
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2023-01-11:01:22:39:INFO] Model loaded successfully for worker : 21
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2023-01-11:01:22:39:INFO] Model loaded successfully for worker : 22
# [2023-01-11 01:22:39 +0000] [23] [INFO] Booting worker with pid: 23
# [2023-01-11 01:22:39 +0000] [24] [INFO] Booting worker with pid: 24
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2023-01-11:01:22:39:INFO] Model loaded successfully for worker : 23
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2023-01-11:01:22:39:INFO] Model loaded successfully for worker : 24
# [2023-01-11:01:22:46:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:46:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:46:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:46:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:47:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:47:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:46:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:46:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:46:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:46:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:47:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:47:INFO] Determined delimiter of CSV input is ','
# 2023-01-11T01:22:43.511:[sagemaker logs]: MaxConcurrentTransforms=4, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# [2023-01-11:01:22:48:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:48:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:48:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:48:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:50:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:50:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:50:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:50:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:51:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:51:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:50:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:50:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:50:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:50:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:51:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:51:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:52:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:52:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:52:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:52:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:54:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:54:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:54:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:54:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:54:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:54:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:54:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:54:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:56:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:56:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:56:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:56:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:56:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:56:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:56:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:56:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:56:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:56:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:56:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:56:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:59:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:00:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:00:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:59:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:00:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:00:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:01:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:01:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:01:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:01:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:01:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:01:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:01:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:01:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:03:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:03:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:03:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:03:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:03:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:03:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:03:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:03:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:05:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:05:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:05:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:05:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:06:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:06:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:05:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:05:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:05:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:05:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:06:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:06:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:07:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:07:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:07:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:07:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:10:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:10:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:10:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:10:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:10:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:10:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:10:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:10:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:11:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:11:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:11:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:11:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:13:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:13:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:13:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:13:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:13:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:13:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:13:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:13:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:15:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:15:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:15:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:15:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:15:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:15:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:15:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:16:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:15:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:15:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:15:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:15:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:15:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:15:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:15:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:16:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:19:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:19:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:19:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:19:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:19:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:19:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:19:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:19:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:19:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:19:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:19:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:19:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:19:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:19:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:19:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:19:INFO] Determined delimiter of CSV input is ','

# %% [markdown]
# Currently the transform job is running but it is doing so in the background. Since we wish to wait until the transform job is done and we would like a bit of feedback we can run the `wait()` method.

# %%
xgb_transformer.wait()
# Out:
# Arguments: serve
# [2023-01-11 01:22:39 +0000] [1] [INFO] Starting gunicorn 19.9.0
# [2023-01-11 01:22:39 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2023-01-11 01:22:39 +0000] [1] [INFO] Using worker: gevent
# [2023-01-11 01:22:39 +0000] [21] [INFO] Booting worker with pid: 21
# [2023-01-11 01:22:39 +0000] [22] [INFO] Booting worker with pid: 22
# Arguments: serve
# [2023-01-11 01:22:39 +0000] [1] [INFO] Starting gunicorn 19.9.0
# [2023-01-11 01:22:39 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2023-01-11 01:22:39 +0000] [1] [INFO] Using worker: gevent
# [2023-01-11 01:22:39 +0000] [21] [INFO] Booting worker with pid: 21
# [2023-01-11 01:22:39 +0000] [22] [INFO] Booting worker with pid: 22
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2023-01-11:01:22:39:INFO] Model loaded successfully for worker : 21
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2023-01-11:01:22:39:INFO] Model loaded successfully for worker : 22
# [2023-01-11 01:22:39 +0000] [23] [INFO] Booting worker with pid: 23
# [2023-01-11 01:22:39 +0000] [24] [INFO] Booting worker with pid: 24
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2023-01-11:01:22:39:INFO] Model loaded successfully for worker : 23
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2023-01-11:01:22:39:INFO] Model loaded successfully for worker : 24
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2023-01-11:01:22:39:INFO] Model loaded successfully for worker : 21
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2023-01-11:01:22:39:INFO] Model loaded successfully for worker : 22
# [2023-01-11 01:22:39 +0000] [23] [INFO] Booting worker with pid: 23
# [2023-01-11 01:22:39 +0000] [24] [INFO] Booting worker with pid: 24
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2023-01-11:01:22:39:INFO] Model loaded successfully for worker : 23
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2023-01-11:01:22:39:INFO] Model loaded successfully for worker : 24
# [2023-01-11:01:22:46:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:46:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:46:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:46:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:47:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:47:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:46:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:46:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:46:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:46:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:47:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:47:INFO] Determined delimiter of CSV input is ','
# 2023-01-11T01:22:43.511:[sagemaker logs]: MaxConcurrentTransforms=4, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# [2023-01-11:01:22:48:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:48:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:48:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:48:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:50:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:50:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:50:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:50:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:51:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:51:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:50:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:50:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:50:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:50:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:51:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:51:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:52:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:52:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:52:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:52:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:54:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:54:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:54:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:54:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:54:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:54:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:54:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:54:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:56:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:56:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:56:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:56:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:56:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:56:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:56:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:56:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:56:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:56:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:56:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:56:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:58:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:58:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:58:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:58:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:59:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:59:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:00:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:00:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:22:59:INFO] Sniff delimiter as ','
# [2023-01-11:01:22:59:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:00:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:00:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:01:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:01:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:01:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:01:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:01:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:01:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:01:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:01:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:03:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:03:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:03:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:03:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:03:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:03:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:03:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:03:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:05:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:05:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:05:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:05:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:06:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:06:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:05:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:05:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:05:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:05:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:06:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:06:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:07:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:07:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:07:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:07:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:10:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:10:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:10:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:10:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:10:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:10:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:10:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:10:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:10:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:10:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:10:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:10:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:11:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:11:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:11:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:11:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:13:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:13:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:13:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:13:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:13:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:13:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:13:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:13:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:15:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:15:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:15:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:15:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:15:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:15:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:15:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:16:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:15:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:15:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:15:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:15:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:15:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:15:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:15:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:16:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:19:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:19:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:19:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:19:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:19:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:19:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:19:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:19:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:19:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:19:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:19:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:19:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:19:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:19:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:19:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:19:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:23:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:23:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:23:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:23:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:23:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:23:INFO] Determined delimiter of CSV input is ','
# [2023-01-11:01:23:23:INFO] Sniff delimiter as ','
# [2023-01-11:01:23:23:INFO] Determined delimiter of CSV input is ','

# %% [markdown]
# Now the transform job has executed and the result, the estimated sentiment of each review, has been saved on S3. Since we would rather work on this file locally we can perform a bit of notebook magic to copy the file to the `data_dir`.

# %%
# !aws s3 cp --recursive $xgb_transformer.output_path $data_dir
# Out:
# download: s3://sagemaker-us-east-1-167257913878/xgboost-2023-01-11-01-16-54-288/test.csv.out to ../data/xgboost/test.csv.out

# %% [markdown]
# The last step is now to read in the output from our model, convert the output to something a little more usable, in this case we want the sentiment to be either `1` (positive) or `0` (negative), and then compare to the ground truth labels.

# %%
predictions = pd.read_csv(os.path.join(data_dir, 'test.csv.out'), header=None)
predictions = [round(num) for num in predictions.squeeze().values]

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test_y, predictions)
# Out:
# 0.86484

# %% [markdown]
# ## Optional: Clean up

# %%
# First we will remove all of the files contained in the data_dir directory
# !rm $data_dir/*

# And then we delete the directory itself
# !rmdir $data_dir

# Similarly we will remove the files in the cache_dir directory and the directory itself
# !rm $cache_dir/*
# !rmdir $cache_dir
